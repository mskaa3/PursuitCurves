# %% [markdown]
# # Krzywe Pościgowe

# %% [markdown]
# ## Spis treści
#
# - 1 [Wstęp](#1)
#     - 1.1 [Historia krzywych pogoni w pigułce](#1.1)
#     - 1.2 [Motywacje i cel](#1.2)

# %% [markdown]
# ## Wstęp <a class="anchor" id="1"></a>
# Na wstępie przyjrzyjmy się następującym zdarzeniom: pies goniący zająca, grupa osób próbująca dobiec do odjeżdżającego autobusu oraz myśliwiec ścigający wroga.
#
# *Co łączy przytoczone zjawiska?*
#
# W każdym z nich występują **„ścigający” oraz  „ścigani”** będący w ruchu i poruszający się po jakichś torach.
#
# *Zatem gdzie jest tutaj matematyka?*
#
# Okazuje się, że do opisu toru ruchu ścigających możemy zastosować narzędzie matematyczne nazywane **krzywymi pościgowymi**. Krzywa pogoni (zamiennie do krzywej pościgu) zawsze zmierza w kierunku ściganego, który porusza się po jakiejś krzywej.
#
# ### Historia krzywych pogoni w pigułce <a class="anchor" id="1.1"></a>
# Mówiąc o krzywych pościgu nie można pominąć bogatej historii tego zjawiska.
# Swoje zaczątki ma ona już w  V w. p.n.e., kiedy to grecki uczony Zenon z Elei wprowadził *,,Paradoks Achillesa”*[1]. Mówi on o tym, że Achilles nigdy nie dogoni żółwia, który zaczął bieg od połowy dystansu, mimo że biegnie od niego 2 razy szybciej. Tak właśnie wprowadzony został główny problem jaki badają krzywe pościgowe, a mianowicie: ***czy ścigający dogoni ściganego?***
#
# Kolejną osobistością, która przyjrzała się temu tematowi był Leonardo da Vinci. Badał on problem psa goniącego człowieka, który biegnie po linii prostej. Krzywa po jakiej biegnie pies otrzymała nazwę „psiej krzywej pogoni”. Zasadniczo jednak nie nazywa się go twórcą krzywych pościgu, gdyż na ich skrupulatne wyjaśnienie musieliśmy poczekać do pojawienia się równań różniczkowych. [2]
#
# W taki sposób do XVIII w. n.e. nic się nie działo, aż tym zjawiskiem zajął się człowiek nazywany założycielem krzywych pogoni, a mianowicie francuz **Pierre Bouger**. W 1732 r. sformułował on pierwszy problem pościgowy (obejmujący statek piracki ścigający statek handlowy), używając do jego opisu Newtonowskiego rachunku różniczkowego[3]. Pierre-Louis Moreau de Maupertuis uogólnił problem pościgu w 1735 roku, tak aby ścigany mógł podążać ścieżkami innymi niż linie proste[4].
#
# Warto wspomnieć że używana przez nas nazwa *krzywe pościgowe (pursuit curves)* pierwszy raz była użyta przez George Boole'a w 1859 roku w dziele *“Treatise on differential equations”*. [5?]
#
# ### Motywacje i cel <a class="anchor" id="1.2"></a>
# Historia tych krzywych jest ciekawa, niemniej jak sam ich temat. Motywacją do badania krzywych pościgowych jest fakt, że są one niezwykle przydatne w opisywaniu ruchu obiektów i dzięki nim możemy lepiej zrozumieć ich zachowanie, a także przewidywać ich przyszły ruch.
#
# Celami tego projektu są: **analiza zachowań goniących obiektów, dla różnych krzywych oraz różnej liczbie obiektów oraz zbadanie ich zastosowań w różnych dziedzinach**. Chcemy także przedstawić różne metody ich obliczania oraz omówić praktyczne zastosowania krzywych pościgowych w różnych sytuacjach.

# %%
# tak mozna wpisywać równania (zainstalowałam mathjax w cmd)

# %% [markdown]
# $$
# \frac{a+b}{c+d} \\
# \sqrt[3]{27} = 3
# $$

# %% [markdown]
# ### Podstawy teoretyczne <a class="anchor" id="1.2"></a>
# Podczas pościgu ścigający obiera kierunek w którym widzi ściganego, czyli jego pozycję w danej chwili czasu. W rzeczywistości oznacza to, że ścigany zawsze znajduje się na prostej stycznej do toru ruchu ścigającego, innymi słowami - omawianej krzywej pościgu. We wszystkich rozpatrywanych problemach zakładamy, że zarówno ścigany jak i ścigający poruszają się ze stałą prędkością, a stosunek tych prędkości decyduje o tym czy pościg zakończy się porażką czy sukcesem, w przypadku sukcesu wyznacza miejsce spotkania się obu obiektów i ile czasu zajmie pościg.
#
# **Przypadek 1: Ścigany porusza się po linii prostej**
#
# ![image.png](attachment:image.png)
#
# W najbardziej klasycznym przypadku uciekinier porusza się w stałym kierunku czyli po linii prostej. Zobrazownie problemu w układzie kartezjańskim pozwoli nam na lepsze zrozumienie zależności między poruszającymi się obiektami i znalezienie krzywej po której będzie poruszał się ścigający.
# Załóżmy, że uciekający jest punktem **A**, który startuje z punktu **[X,0]** z prędkością **v**. W danej chwili **t** jego pozycję można zatem opisać przy pomocy współrzędnych **[X,v*t]**. Niech ścigający będzie punktem **B** startującym z początku układu i poruszającym się ze stałą prędkością **w** w kierunku punktu **A**, a jego pozycję w czasie t możemy opisać współrzędnymi **[x,y]**. Zatem linię styczną możemy opisać jako:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# $$
# \frac{dy}{dx}= \frac{vt-y}{X-x}\\
# $$

# %% [markdown]
# Znając prędkość z jaką porusza się punkt B wiemy również, że odległość jaką przemierza w czasie **t** to **w*t**.  Odległość tą można także przedstawić używając wzoru na długość łuku. Mamy więc:
# $$
# w*t=\ \int_{0}^{x} \sqrt{1+y’(u)^2} \,du \
# $$

# %% [markdown]
# Rozwiązując oba równania dla t:

# %% [markdown]
# $$
# t=\frac{y+(x-X)*\frac{dy}{dx}}{v}
# $$
# oraz:

# %% [markdown]
# $$
# t=\frac{1}{w} \int_{0}^{x} \sqrt{1+(\frac{dy}{du})^2} \,du \
# $$
# przyrównując do siebie otrzymujemy:

# %% [markdown]
# $$
# \frac{y+(x-X)*\frac{dy}{dx}}{v}=\frac{1}{w} \int_{0}^{x} \sqrt{1+(\frac{dy}{du})^2} \,du \\
# $$

# %% [markdown]
# Podstawiając **p(x)=dy/dx**

# %% [markdown]
# $$
# \frac{y+(x-X)*p(x)}{v}=\frac{1}{w} \int_{0}^{x} \sqrt{1+p^2(u)} \,du \\
# $$

# %% [markdown]
# Następnie używając wzoru Leibniza (DODAC OBJAŚNEINIE):
#
# $$
# \frac{1}{v}*\frac{dy}{dx}-\frac{x-X}{v}*\frac{dp}{dx}-\frac{1}{v}*p(x)=\frac{1}{w} * \sqrt{1+p^2(x)}
# $$

# %% [markdown]
# $$
# \frac{dp}{dx}*(x-X)=-\frac{v}{w}*\sqrt{1+p^2(x)}
# $$

# %% [markdown]
# W powyższym wzorze pojawia się wcześniej wspomniany stosunek prędkości, który decysuje o sukcesie pościgu. Dla uproszczenia dalszych oblcizeń przyjmujemy **k=v/w**

# %% [markdown]
# Rozdzielając zmiennych pozwoli nam na scałkowanie:
# $$
# \frac{dp}{\sqrt{1+p^2}}=-\frac{kdx}{x-X}
# $$
# $$
# \ln(p+\sqrt{1+p^2})+C=-k*\ln(X-x)
# $$

# %% [markdown]
# Miejsca startu obu obiektów są tak na prawdę warunkami początkowymi naszgo równania. W chwili t=0 oba obiekty znajduja się na osi OX, więc p=0. Korzystając z tego faktu możemy obliczyc stałą C:

# %% [markdown]
# (dodać szczegółowe obliczenia)

# %% [markdown]
# $$
# C=-k*\ln(X)
# $$
# Zatem:
# $$
# \ln(p+\sqrt{1+p^2})-k*\ln(X)=-k*\ln(X-x)
# $$
# $$
# \ln(p+\sqrt{1+p^2})-k*(\ln(X)-\ln(X-x))=0
# $$
# Stosując właściwości logarytmów:
# $$
# \ln(p+\sqrt{1+p^2})+\ln(\frac{X}{X-x})^{-k}=0
# $$
# $$
# \ln(p+\sqrt{1+p^2}*(1-\frac{x}{X})^{k})=0
# $$
# $$
# p+\sqrt{1+p^2}*(1-\frac{x}{X})^{k}=1
# $$
# $$
# p+\sqrt{1+p^2}=\frac{1}{(1-\frac{x}{X})^{k}}
# $$
# $$
# \sqrt{1+p^2}=\frac{1}{(1-\frac{x}{X})^{k}}-p
# $$
# Podnosząc obustronnie do kwadratu
# $$
#     1+p^2=(\frac{1}{(1-\frac{x}{X})^{k}})^2-2*p*(\frac{1}{(1-\frac{x}{X})^{k}})+p^2
# $$
# $$
# 1=(\frac{1}{(1-\frac{x}{X})^{k}})^2-2*p*(\frac{1}{(1-\frac{x}{X})^{k}})
# $$
# $$
# \frac{1}{(\frac{1}{(1-\frac{x}{X})^{k}})}-(\frac{1}{(1-\frac{x}{X})^{k}})=-2*p
# $$
# $$
# p=\frac{1}{2}*(\frac{1}{(1-\frac{x}{X})^{k}}-\frac{1}{(\frac{1}{(1-\frac{x}{X})^{k}})})
# $$
# $$
# \frac{dy}{dx}=p(x)=\frac{1}{2}*((1-\frac{x}{X})^{-k}-(1-\frac{x}{X})^{k})
# $$

# %% [markdown]
# Możemy teraz rozwiązać dla y(x) całkując
# $$
# dy =( \frac{1}{2}*((1-\frac{x}{X})^{-k}-(1-\frac{x}{X})^{k})) dx
# $$
# $$
# y(x)+C=\ \int_ {}{}\frac{1}{2}*(\frac{1}{(1-\frac{x}{X})^{k}} )\,du - \int_ {}{}\frac{1}{2}*((1-\frac{x}{X})^{k})\,du \
# $$

# %% [markdown]
# Podstawiając $$ z=(1-\frac{x}{X})\hspace{1cm} i  \hspace{1cm}  dx=-X dz$$

# %% [markdown]
# Możemy policzyć

# %% [markdown]
# $$
# y(x)+C=\ \frac{1}{2}*\int_ {}{}(\frac{-X dz}{z^k} )- \frac{1}{2}*\int_ {}{} -X*z^k dz
# $$
# $$
# y(x)+C= \frac{-X}{2}*(\frac{-z^{-k+1}}{-k+1} )+ \frac{X}{2}*(\frac{z^{k+1}}{k+1} )
# $$
# $$
# y(x)+C= \frac{X}{2}*(-\frac{z^{-k}*z}{-k+1} )+ \frac{X}{2}*(\frac{z^{k}*z}{k+1} )
# $$
# $$
# y(x)+C= \frac{X*z}{2}*((-\frac{z^{-k}}{-k+1})-(\frac{z^{k}}{k+1} ))
# $$
# I podstawiając z powrotem za **z**
#
# $$
# y(x)+C= \frac{X}{2}*(1-\frac{x}{X})*[(-\frac{(1-\frac{x}{X})^{-k}}{-k+1})-(\frac{(1-\frac{x}{X})^{k}}{k+1} )]
# $$
# Ponownie biorąc pod uwagę warunki początkowe y(0)=0 wyliczamy stałą całkowania
# $$
# 0+C= \frac{X}{2}*(1-\frac{0}{X})*[(-\frac{(1-\frac{0}{X})^{-k}}{-k+1})-(\frac{(1-\frac{0}{X})^{k}}{k+1} )]
# $$
# $$
# C= \frac{X}{2}*[(-\frac{1^{-k}}{-k+1})-(\frac{1^{k}}{k+1} )]=-X*\frac{k}{1-k^2}
# $$
# Podstawiając do równania otrzymujemy ostateczny wzór na krzywą pościgu y=y(x) w sytuacji w której uciekający porusza się po linii prostej:
# $$
# y(x)= \frac{X}{2}*(1-\frac{x}{X})*[(-\frac{(1-\frac{x}{X})^{-k}}{-k+1})-(\frac{(1-\frac{x}{X})^{k}}{k+1} )]+X*\frac{k}{1-k^2}
# $$
# gdzie **k=v/w**

# %% [markdown]
# Kiedy zatem poscig opisany ową krzywą kończy się sukcesem?
# Zauważmy, ze moment "złapania" uciekającego to moment w którym X=x, co powoduje, że druga część nawiasu się zeruje, a punktem w którym następuje złapanie jest $$[X,X*\frac{k}{1-k^2}]$$
# Jeśli przykładowo stosunek prędkości jest równy *k=2/3* to punkt złapania to *[X,X*6/5]*.
#
# Łatwo zauważyć, że granica funkcji kiedy stosunek *k* zbliża się do 1 będzie wynosić nieskończoność, co oznacza oczywiście, że pościg kończy się porażką.
#
# Przypadek w którym *k=1* należy rozważać osobno ze względu na dzielenie przez zero. Wracając do równania (OZNACZYĆ NUMERAMI RÓWNANIA) podstawmy k=1.
# $$
# dy =( \frac{1}{2}*((1-\frac{x}{X})^{-1}-(1-\frac{x}{X})^{1})) dx
# $$
# $$
# y(x)+C=\ \int_ {}{}\frac{1}{2}*(\frac{1}{(1-\frac{x}{X})} )\,du - \int_ {}{}\frac{1}{2}*((1-\frac{x}{X}))\,du \
# $$
# Używając tego samogo podstawienia **z** otrzymujemy
# $$
# y(x)+C= \frac{-X}{2}*ln(z)+\frac{X}{2}*\frac{1}{2}*z^2=\frac{X}{2}*[\frac{1}{2}*(1-\frac{x}{X})^2-ln(1-\frac{x}{X})]
# $$
# Ponownie wyliczając C z warunków początkowych
# $$
# C=\frac{X}{2}*[\frac{1}{2}*(1-\frac{0}{X})^2-ln(1-\frac{0}{X})]=\frac{X}{4}
# $$
# Tak więc dla *k=1* wzór y=y(x) opisujący krzywą pościgu ma postać
# $$
# y(x)=\frac{X}{2}*[\frac{1}{2}*(1-\frac{x}{X})^2-ln(1-\frac{x}{X})]-\frac{X}{4}
# $$

# %% [markdown]
# ## Bibliografia <a class="anchor" id="7"></a>
# - [1] https://www.pap.pl/mediaroom/1001648%2Cwzrosl-ruch-na-drogach-krajowych-synteza-wynikow-generalnego-pomiaru-ruchu-202021
# - [2] T. Tsuboi, Traffic Flow Analysis and Management, opublikowano 05.02.2021, https://www.intechopen.com/chapters/75082
# - [3] https://www.gov.pl/web/gddkia/generalny-pomiar-ruchu-20202021
